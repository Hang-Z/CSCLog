# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import torch
from sklearn.manifold import TSNE

# %%
data_X = torch.load('case_x.pth')
y = torch.load('case_y.pth')

# %%
tsne = TSNE(n_components=2, random_state=0)

# %%
tsne_obj= tsne.fit_transform(data_X)

tsne_df = pd.DataFrame({'X':tsne_obj[:,0],
                        'Y':tsne_obj[:,1],
                        'Log Templates':y})

# %%
# 全部训练样本
plt.figure(figsize=(12, 12))
sns.scatterplot(x="X", y="Y",
              hue="Log Templates",
              palette=sns.color_palette(),
              legend='full',
              data=tsne_df)
plt.xticks([])  # 去掉横坐标值
plt.yticks([])  # 去掉纵坐标值
plt.show()
# Out:
# E:\applist\Anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:6: UserWarning:
# The palette list has fewer values (10) than needed (11) and will cycle, which may produce an uninterpretable plot.

# %%
data_X = torch.load('deep_case_x.pth')
y = torch.load('deep_case_y.pth')

# %%
tsne = TSNE(n_components=2, random_state=0)

# %%
tsne_obj= tsne.fit_transform(data_X)

tsne_df = pd.DataFrame({'X':tsne_obj[:,0],
                        'Y':tsne_obj[:,1],
                        'Log Templates':y})

# %%
plt.figure(figsize=(12, 12))
sns.scatterplot(x="X", y="Y",
              hue="Log Templates",
              palette=sns.color_palette(),
              legend='full',
              data=tsne_df)
plt.xticks([])  # 去掉横坐标值
plt.yticks([])  # 去掉纵坐标值
plt.show()
# Out:
# E:\applist\Anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:6: UserWarning:
# The palette list has fewer values (10) than needed (11) and will cycle, which may produce an uninterpretable plot.
